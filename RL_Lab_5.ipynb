# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51096/Reinforcement_learning/blob/main/RL_Lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. CartPole – Static Input

# %%
import gymnasium as gym

env = gym.make("CartPole-v1")

state, info = env.reset()

total_reward = 0
steps = 0

terminated = False
truncated = False

while not (terminated or truncated):

    # Static action
    action = 1

    next_state, reward, terminated, truncated, info = env.step(action)

    print("State:", state)
    print("Action:", action)
    print("Reward:", reward)
    print("Next State:", next_state)

    total_reward += reward
    steps += 1

    state = next_state

average_reward = total_reward / steps

print("Total Reward =", total_reward)
print("Average Reward =", average_reward)
print("Total Steps =", steps)

env.close()
# Out:
# State: [-0.02765897 -0.01375388 -0.0326059  -0.01120501]
# Action: 1
# Reward: 1.0
# Next State: [-0.02793405  0.18182014 -0.03283    -0.31399456]
# State: [-0.02793405  0.18182014 -0.03283    -0.31399456]
# Action: 1
# Reward: 1.0
# Next State: [-0.02429765  0.37739402 -0.03910989 -0.6168476 ]
# State: [-0.02429765  0.37739402 -0.03910989 -0.6168476 ]
# Action: 1
# Reward: 1.0
# Next State: [-0.01674977  0.5730399  -0.05144684 -0.92158735]
# State: [-0.01674977  0.5730399  -0.05144684 -0.92158735]
# Action: 1
# Reward: 1.0
# Next State: [-0.00528897  0.76881784 -0.06987859 -1.2299844 ]
# State: [-0.00528897  0.76881784 -0.06987859 -1.2299844 ]
# Action: 1
# Reward: 1.0
# Next State: [ 0.01008739  0.9647658  -0.09447828 -1.5437165 ]
# State: [ 0.01008739  0.9647658  -0.09447828 -1.5437165 ]
# Action: 1
# Reward: 1.0
# Next State: [ 0.0293827  1.1608876 -0.1253526 -1.8643227]
# State: [ 0.0293827  1.1608876 -0.1253526 -1.8643227]
# Action: 1
# Reward: 1.0
# ...

# %% [markdown]
# 2. MountainCar – Static Input

# %%
import gymnasium as gym

env = gym.make("MountainCar-v0")

state, info = env.reset()

total_reward = 0
steps = 0

terminated = False
truncated = False

while not (terminated or truncated):

    # Static action
    action = 2

    next_state, reward, terminated, truncated, info = env.step(action)

    print("State:", state)
    print("Action:", action)
    print("Reward:", reward)
    print("Next State:", next_state)

    total_reward += reward
    steps += 1

    state = next_state

average_reward = total_reward / steps

print("Total Reward =", total_reward)
print("Average Reward =", average_reward)
print("Total Steps =", steps)

env.close()
# Out:
# State: [-0.56100905  0.        ]
# Action: 2
# Reward: -1.0
# Next State: [-0.5597291   0.00127999]
# State: [-0.5597291   0.00127999]
# Action: 2
# Reward: -1.0
# Next State: [-0.5571787   0.00255044]
# State: [-0.5571787   0.00255044]
# Action: 2
# Reward: -1.0
# Next State: [-0.5533768   0.00380186]
# State: [-0.5533768   0.00380186]
# Action: 2
# Reward: -1.0
# Next State: [-0.5483519  0.0050249]
# State: [-0.5483519  0.0050249]
# Action: 2
# Reward: -1.0
# Next State: [-0.5421415   0.00621038]
# State: [-0.5421415   0.00621038]
# Action: 2
# Reward: -1.0
# Next State: [-0.5347921   0.00734937]
# State: [-0.5347921   0.00734937]
# Action: 2
# Reward: -1.0
# Next State: [-0.52635884  0.00843331]
# State: [-0.52635884  0.00843331]
# Action: 2
# Reward: -1.0
# Next State: [-0.51690483  0.00945401]
# State: [-0.51690483  0.00945401]
# Action: 2
# Reward: -1.0
# Next State: [-0.506501    0.01040381]
# State: [-0.506501    0.01040381]
# Action: 2
# Reward: -1.0
# ...

# %% [markdown]
# 3. FrozenLake – Static Input

# %%
import gymnasium as gym

env = gym.make("FrozenLake-v1", is_slippery=False)

state, info = env.reset()

total_reward = 0
steps = 0

terminated = False
truncated = False

while not (terminated or truncated):

    # Static action
    action = 1

    next_state, reward, terminated, truncated, info = env.step(action)

    print("State:", state)
    print("Action:", action)
    print("Reward:", reward)
    print("Next State:", next_state)

    total_reward += reward
    steps += 1

    state = next_state

average_reward = total_reward / steps

print("Total Reward =", total_reward)
print("Average Reward =", average_reward)
print("Total Steps =", steps)

env.close()
# Out:
# State: 0
# Action: 1
# Reward: 0
# Next State: 4
# State: 4
# Action: 1
# Reward: 0
# Next State: 8
# State: 8
# Action: 1
# Reward: 0
# Next State: 12
# Total Reward = 0
# Average Reward = 0.0
# Total Steps = 3
